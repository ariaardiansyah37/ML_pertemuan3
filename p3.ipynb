# %% [markdown]
# <a href="https://colab.research.google.com/github/ariaardiansyah37/ML_pertemuan3/blob/main/p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn import metrics

# %%
df = pd.read_excel("/content/DATA RUMAH.xlsx")
df.head()
# Out:
#    NO                                         NAMA RUMAH       HARGA   LB  \
# 0   1  Rumah Murah Hook Tebet Timur, Tebet, Jakarta S...  3800000000  220
# 1   2  Rumah Modern di Tebet dekat Stasiun, Tebet, Ja...  4600000000  180
# 2   3  Rumah Mewah 2 Lantai Hanya 3 Menit Ke Tebet, T...  3000000000  267
# 3   4           Rumah Baru Tebet, Tebet, Jakarta Selatan   430000000   40
# 4   5  Rumah Bagus Tebet komp Gudang Peluru lt 350m, ...  9000000000  400
#
#     LT  KT  KM  GRS
# 0  220   3   3    0
# 1  137   4   3    2
# 2  250   4   4    4
# 3   25   2   2    0
# 4  355   6   5    3

# %%
df.tail(7)
# Out:
#         NO                                         NAMA RUMAH        HARGA  \
# 1003  1004  Rumah 2lantai Akses 2mobil Di Bukit Duri Tebet...    600000000
# 1004  1005  Rumah Strategis 100meter Ke Jl Supomo Di Mente...   2600000000
# 1005  1006  Rumah Strategis Akses Jalan 2mobil Di Menteng ...   9000000000
# 1006  1007             Tebet Rumah Siap Huni Jln 2 Mbl Nyaman   4000000000
# 1007  1008        Di Kebun Baru Rumah Terawat, Area Strategis   4000000000
# 1008  1009  Dijual Cepat Rumah Komp Depkeu Dr Soepomo Tebe...  19000000000
# 1009  1010                Dijual Rumah Kokoh Di Gudang Peluru  10500000000
#
#        LB   LT  KT  KM  GRS
# 1003   60   30   2   2    0
# 1004  100  140   3   2    1
# 1005  450  550  10  10    3
# 1006  160  140   4   3    2
# 1007  139  230   4   4    1
# 1008  360  606   7   4    0
# 1009  420  430   7   4    2

# %%
print(df.dtypes)
# Out:
# NO             int64
# NAMA RUMAH    object
# HARGA          int64
# LB             int64
# LT             int64
# KT             int64
# KM             int64
# GRS            int64
# dtype: object

# %%
df_noid = df.iloc[:,2:]
df_noid
# Out:
#             HARGA   LB   LT  KT  KM  GRS
# 0      3800000000  220  220   3   3    0
# 1      4600000000  180  137   4   3    2
# 2      3000000000  267  250   4   4    4
# 3       430000000   40   25   2   2    0
# 4      9000000000  400  355   6   5    3
# ...           ...  ...  ...  ..  ..  ...
# 1005   9000000000  450  550  10  10    3
# 1006   4000000000  160  140   4   3    2
# 1007   4000000000  139  230   4   4    1
# 1008  19000000000  360  606   7   4    0
# 1009  10500000000  420  430   7   4    2
#
# [1010 rows x 6 columns]

# %%
df1 = df_noid.sort_values(by="HARGA",ascending=True)
df1.head(10)
# Out:
#           HARGA   LB  LT  KT  KM  GRS
# 3     430000000   40  25   2   2    0
# 680   600000000   60  30   2   1    0
# 1003  600000000   60  30   2   2    0
# 921   650000000   50  55   2   1    0
# 204   690000000   90  50   3   1    0
# 22    700000000   75  75   2   3    0
# 248   750000000   80  78   3   1    0
# 803   750000000  100  78   3   1    0
# 75    750000000   78  80   3   2    0
# 820   850000000   56  56   4   2    0

# %%
df1 = df_noid.sort_values(by=["LB","LT"],  ascending=[True,False])
df1.head(10)
# Out:
#            HARGA  LB   LT  KT  KM  GRS
# 3      430000000  40   25   2   2    0
# 921    650000000  50   55   2   1    0
# 820    850000000  56   56   4   2    0
# 680    600000000  60   30   2   1    0
# 1003   600000000  60   30   2   2    0
# 738   3000000000  62   90   5   3    0
# 645   1100000000  63  300   3   1    1
# 113   2200000000  70   98   2   1    0
# 999   1100000000  70   70   2   1    0
# 696   2700000000  72   72   4   4    0

# %%
df_noid.describe()
# Out:
#               HARGA           LB           LT           KT           KM  \
# count  1.010000e+03  1010.000000  1010.000000  1010.000000  1010.000000
# mean   7.628987e+09   276.539604   237.432673     4.668317     3.607921
# std    7.340946e+09   177.864557   179.957604     1.572776     1.420066
# min    4.300000e+08    40.000000    25.000000     2.000000     1.000000
# 25%    3.262500e+09   150.000000   130.000000     4.000000     3.000000
# 50%    5.000000e+09   216.500000   165.000000     4.000000     3.000000
# 75%    9.000000e+09   350.000000   290.000000     5.000000     4.000000
# max    6.500000e+10  1126.000000  1400.000000    10.000000    10.000000
#
#                GRS
# count  1010.000000
# mean      1.920792
# std       1.510998
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max      10.000000

# %%
df_noid[['LB' , 'LT' , 'KT' , 'KM']].mean()
# Out:
# LB    276.539604
# LT    237.432673
# KT      4.668317
# KM      3.607921
# dtype: float64

# %%
df_noid[['LB' , 'LT' , 'KT' , 'KM']].median()
# Out:
# LB    216.5
# LT    165.0
# KT      4.0
# KM      3.0
# dtype: float64

# %%
df_noid[['HARGA']].mode()
# Out:
#         HARGA
# 0  3500000000

# %%
df_noid.quantile(0.75)
# Out:
# HARGA    9.000000e+09
# LB       3.500000e+02
# LT       2.900000e+02
# KT       5.000000e+00
# KM       4.000000e+00
# GRS      2.000000e+00
# Name: 0.75, dtype: float64

# %%
df_noid[['HARGA']].var(),df_noid[['HARGA']].std()
# Out:
# (HARGA    5.388949e+19
#  dtype: float64,
#  HARGA    7.340946e+09
#  dtype: float64)

# %%
mean =df_noid[['HARGA']].mean()
stdev =df_noid[['HARGA']].std()
iso =(df_noid[['HARGA']] < mean - 3*stdev) | (df_noid[['HARGA']] > mean +3*stdev)
df1 = df_noid[['HARGA' , 'LT']].assign(is_outlier=iso)
df1.loc[df1['is_outlier']]
# Out:
#            HARGA    LT  is_outlier
# 31   42000000000   600        True
# 50   41000000000   600        True
# 103  30000000000   752        True
# 122  42000000000   600        True
# 165  30000000000   498        True
# 219  38000000000   720        True
# 283  65000000000   200        True
# 289  30000000000   312        True
# 448  35000000000   469        True
# 469  30900000000   670        True
# 470  55000000000  1075        True
# 474  55000000000  1224        True
# 503  30000000000   672        True
# 516  37000000000   720        True
# 567  35000000000  1400        True
# 667  31000000000   670        True
# 715  30000000000   498        True
# 739  30000000000   703        True
# 751  42000000000   624        True
# 826  30000000000   703        True
# 835  30000000000   750        True
# 837  35000000000   700        True
# 839  30000000000   498        True
# 935  35000000000   600        True
